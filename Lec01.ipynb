# %%
print(7)

# %%
print("Hello World",1.45,True)

# %%
#Now  a python print function has a seperator which allows us to print multiple variables with a space.Here  i am gonna override it .

print ("Hello World",1.45,True,sep="%")

# %%
#Multiple lines ka output hamesha  alag hi line main aayega coz definition main dettings main end =line change hota hai .Here again i am gonna overrride it 

print("Hello")
print("World")

print("Hello",end="+")
print("World")

# %%
# Here type of print function is shown 
type(print)

#type is used to find type of data or function used

# %%
#how many data types are supported in python

#Integr (Very large ones also 1e309,meaning 1*(10^309)) and 0 to 10^308
print(1e309) #gives inf 

print(1e308)

# %%
 #Decimal/Float (Supports 1.73309)(0-1.7*(10^308))

print(1.7e309) #gives inf
print(1.7e308)

# %%
#Boolean (Boolean is not text)

print(True,False)

# %%
#Complex datatype (represents complex numbers )

print(5+6)
print(5+6j) #complex  representation

# %%
#List datatype (C main array is used but here array ka similar milta jult abhai is list )

print([1,2,3,4,5]) 
#Also isme string likh dunga tobhi no dikkat coz traditional array nhi hai

# %%
#Tuple datatype 

print((1,2,3,4,5))

# %%
#Dictionaries :Store data in key:value pairs 

print({'name':'Samarth','age':20,"career":'Aspiring Developer'})

# %%
#Sets  
print({1,2,3,4,5})

# %%
#Variables :Containers sortof to  store data /COntainers for future use 

#How to  create variables:
name='Samarth'
print(name)

#Python is intelligent enough to like guess the datatype of value  stored within it

# %%
# What is Dynamic Typing?
#Python main vaiablee creation time pe hum yeh nhi batate ki variable creation ke time datatype kounsi hogi.This way of declaring is called Dynamic Typing.

#Static Typing is like C declaration of variables

# %%
# What is Dynamic Binding ?

#It is like jaise runtime pe realization like  jaise ek variable in python number bhi  store kar  skta hai and string bhi.Ex:

a='Samarth'
print(a);
a=99
print(a)

# What is Static Binding?
# is like  if variable define hogaya and stores a innt datatyppe to pure program main bas int type ka data hi store karega

# %%
# Keywords and Idenitifiers  

# Keyword:Words reserved by compiler/interpreter.Total of 32 keywords in python.

#Identifiers: words which you select for naming variables,functions,etc

#Rules for writing identifiers:-
        #1. Cannot start with digits
        #2.You can use  uppercase,lowercase,digits  but only underscore can be used as a special chsracter,rest can't be used
        #3. You cannot use keyword as identifiers

# %%
#Input functions:for taking input from user (dynamic software)

name=input("Enter your Name:")

num1=input("Enter first number")
num2=input("Enter second number")
print("Summition of two numbers is:",num1+num2)

# But this way spoose first num is 56 and second is 67 so result printed will be 5667 because the user input is treated as string so summition leads to string concatenation.Hence pehle typecast karna hoga.

#But why so? Because string is a universal format you can store  other datatypes inside of string that's why.

#Solution:Type casting(implicit v/s explicit)

# %%
#Type casting (Implicit)

print(5+5.6)

print(type(5),type(5.6))

#here 5 is integer but 5.6 is float so python converts 5 from int->foat(implicit coz python ne khud se kiya )
# Out:
# 10.6
# <class 'int'> <class 'float'>

# %%
#Explicit type casting

#if implicit typecasting cannot handle thenn we need to do explicit type casting 

#print(4+'4') #gives error 

print(4+int('4')) #now ggives 8 as string 4 gets converted to numeric four 

#But changing complex to numeric gives error coz information loos which is avoided by python  

#Multiple conversions like float(),str(),etc.
# Out:
# 8

# %%
#Literals(variable ke andar ki raw value )

a=0b1010  #Binary Literals(0b python ko bolta hai ki bhai binary  main de raha hoon )
b=0o310    #Octal representation
c=0x12c    #hexadecimal literal 

#Float Literals 

float_1=10.5  #normal representatiom
float_2=1.5e2 #scientific representation (bhale hi iski value is 150(1.5*10^2) but flaot hi consider hoga )
float_3=1.5e-3 # 1.5*10^-3

#Complex Literals

x=3.14j #for real part x.real and for imaginary x.imag

# %%
#Strings :

string='Ths ython'
strings="THis python"
char="C"
multiline_str=""" This is  a multiline string with more than one line of code """
#for multiline string use triple inverted comma 
unicode=u"\U0001f600\U0001F606\U0001F923"
print(unicode)
# unicode(u) is used to handle things other than text like smiley  emojis  
raw_str=r"raw \n string"
# Out:
# 😀😆🤣
# 😀😆🤣

# %%
a=True+4 #In a mathematical expression python treats booleans as nnumerics 
b=False +True+9
print(a,b)
# Out:
# 5 10

# %%
#None used whwn variable bana ke rkhna to hai par value assign nhi karna hai to None kardo 
k=None
print(k)
# Out:
# None
